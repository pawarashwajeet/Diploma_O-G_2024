# %%
print("Hello World")
# Out:
# Hello World

# %%
print("Hello World")
# Out:
# Hello World

# %%
import numpy as np
import matplotlib as plt
import pandas as pd
import seaborn as sns

# %%
print("How are you doing???")
# Out:
# How are you doing???

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import seaborn as sns

# %%
por = np.array([.25,.16,.12,.04])

# %%
por
# Out:
# array([0.25, 0.16, 0.12, 0.04])

# %%
poro_series = pd.Series(data=por, index = ["a", "b", "c","d"])

# %%
poro_series
# Out:
# a    0.25
# b    0.36
# c    0.12
# d    0.54
# dtype: float64

# %%
depth_wise_poro_series = pd.Series(data=por, index = ["1000", "3000", "5000","10000"])

# %%
depth_wise_poro_series
# Out:
# 1000     0.25
# 3000     0.36
# 5000     0.12
# 10000    0.54
# dtype: float64

# %%
depth_wise_poro_series.plot()
# Out:
# <Axes: >

# %%
por
# Out:
# array([0.25, 0.16, 0.12, 0.04])

# %%
depth_wise_poro_series = pd.Series(data=por, index = ["1000", "3000", "5000","10000"])

# %%
depth_wise_poro_series
# Out:
# 1000     0.25
# 3000     0.16
# 5000     0.12
# 10000    0.04
# dtype: float64

# %%
depth_wise_poro_series.plot()
# Out:
# <Axes: >

# %%
my_field_permeabilities = {"rock_A":120,"rock": 100,"rock_C": 80}

# %%
my_field_permeabilities
# Out:
# {'rock_A': 120, 'rock': 100, 'rock_C': 80}

# %%
my_field_perm_series = pd.Series(data = my_field_permeabilities, name ="Permeabilities" )

# %%
my_field_perm_series
# Out:
# rock_A    120
# rock      100
# rock_C     80
# Name: Permeabilities, dtype: int64

# %%
my_field_perm_series.plot()
# Out:
# <Axes: >

# %%
my_field_perm_series.plot(kind = "bar")
# Out:
# <Axes: >

# %%
## Dataframe: Bunch of series together, having a same index
# df = table

# %%
common_depth_index = [1000,1500,2000]

# %%
poro_series_1 = pd.Series(data = [0.35,.21,.17],index = common_depth_index)
poro_series_2 = pd.Series(data = [0.32,.20,.16],index = common_depth_index)

# %%
poro_series_1
# Out:
# 1000    0.35
# 1500    0.21
# 2000    0.17
# dtype: float64

# %%
poro_series_2
# Out:
# 1000    0.32
# 1500    0.20
# 2000    0.16
# dtype: float64

# %%
pd.DataFrame([poro_series_1,poro_series_2]).T
# Out:
#          0     1
# 1000  0.35  0.32
# 1500  0.21  0.20
# 2000  0.17  0.16

# %%
## dataframe using dictionary

# %%
my_field_data = {"depth":[1000,1500,2000],"poro (%)":[35,30,25],"perm (mD)":[500,450,150]}

# %%
my_field_data
# Out:
# {'depth': [1000, 1500, 2000],
#  'poro (%)': [35, 30, 25],
#  'perm (mD)': [500, 450, 150]}

# %%
my_field_data["poro (%)"][1]
# Out:
# 30

# %%
df_field = pd.DataFrame(my_field_data)

# %%
df_field
# Out:
#    depth  poro (%)  perm (mD)
# 0   1000        35        500
# 1   1500        30        450
# 2   2000        25        150

# %%
df_field.plot()
# Out:
# <Axes: >

# %%
df_field.plot(subplots = True)
# Out:
# array([<Axes: >, <Axes: >, <Axes: >], dtype=object)

# %%
## Accessing certain column and row

# %%
df_field
# Out:
#    depth  poro (%)  perm (mD)
# 0   1000        35        500
# 1   1500        30        450
# 2   2000        25        150

# %%
##Accessing column

# %%
df_field[["poro (%)"]]
# Out:
#    poro (%)
# 0        35
# 1        30
# 2        25

# %%
type(df_field[["poro (%)"]])
# Out:
# pandas.core.frame.DataFrame

# %%
df_field[["depth","perm (mD)"]]
# Out:
#    depth  perm (mD)
# 0   1000        500
# 1   1500        450
# 2   2000        150

# %%
df_field.index = df_field["depth"]

# %%
df_field
# Out:
#        depth  poro (%)  perm (mD)
# depth
# 1000    1000        35        500
# 1500    1500        30        450
# 2000    2000        25        150

# %%
### Accessing rows from dataframes
#1. Loc: index label
#2. iloc: index number

# %%
df_field.loc[1500]
# Out:
# depth        1500
# poro (%)       30
# perm (mD)     450
# Name: 1500, dtype: int64

# %%
df_field.iloc[1]
# Out:
# depth        1500
# poro (%)       30
# perm (mD)     450
# Name: 1500, dtype: int64

# %%
depth = np.linspace(1000,5000,10)
porosity = np.linspace(40,10,10)
perm = np.linspace(500,100,10)
reservoir_pressure = np.linspace(3000,4500,10)

# %%
depth
# Out:
# array([1000.        , 1444.44444444, 1888.88888889, 2333.33333333,
#        2777.77777778, 3222.22222222, 3666.66666667, 4111.11111111,
#        4555.55555556, 5000.        ])

# %%
df = pd.DataFrame({"depth":depth,"Porosity":porosity,"Permeability":perm,"reservoir_pressure":reservoir_pressure})

# %%
df
# Out:
#          depth   Porosity  Permeability  reservoir_pressure
# 0  1000.000000  40.000000    500.000000         3000.000000
# 1  1444.444444  36.666667    455.555556         3166.666667
# 2  1888.888889  33.333333    411.111111         3333.333333
# 3  2333.333333  30.000000    366.666667         3500.000000
# 4  2777.777778  26.666667    322.222222         3666.666667
# 5  3222.222222  23.333333    277.777778         3833.333333
# 6  3666.666667  20.000000    233.333333         4000.000000
# 7  4111.111111  16.666667    188.888889         4166.666667
# 8  4555.555556  13.333333    144.444444         4333.333333
# 9  5000.000000  10.000000    100.000000         4500.000000

# %%
df.plot(subplots = True)
# Out:
# array([<Axes: >, <Axes: >, <Axes: >, <Axes: >], dtype=object)

# %%
df.index = df["depth"]

# %%
df
# Out:
#                    depth   Porosity  Permeability  reservoir_pressure
# depth
# 1000.000000  1000.000000  40.000000    500.000000         3000.000000
# 1444.444444  1444.444444  36.666667    455.555556         3166.666667
# 1888.888889  1888.888889  33.333333    411.111111         3333.333333
# 2333.333333  2333.333333  30.000000    366.666667         3500.000000
# 2777.777778  2777.777778  26.666667    322.222222         3666.666667
# 3222.222222  3222.222222  23.333333    277.777778         3833.333333
# 3666.666667  3666.666667  20.000000    233.333333         4000.000000
# 4111.111111  4111.111111  16.666667    188.888889         4166.666667
# 4555.555556  4555.555556  13.333333    144.444444         4333.333333
# 5000.000000  5000.000000  10.000000    100.000000         4500.000000

# %%
df.plot()
# Out:
# <Axes: xlabel='depth'>

# %%
df
# Out:
#                    depth   Porosity  Permeability  reservoir_pressure
# depth
# 1000.000000  1000.000000  40.000000    500.000000         3000.000000
# 1444.444444  1444.444444  36.666667    455.555556         3166.666667
# 1888.888889  1888.888889  33.333333    411.111111         3333.333333
# 2333.333333  2333.333333  30.000000    366.666667         3500.000000
# 2777.777778  2777.777778  26.666667    322.222222         3666.666667
# 3222.222222  3222.222222  23.333333    277.777778         3833.333333
# 3666.666667  3666.666667  20.000000    233.333333         4000.000000
# 4111.111111  4111.111111  16.666667    188.888889         4166.666667
# 4555.555556  4555.555556  13.333333    144.444444         4333.333333
# 5000.000000  5000.000000  10.000000    100.000000         4500.000000

# %%
depth = np.arange(1000,6000,500)
porosity = np.linspace(40,10,10)
perm = np.linspace(500,100,10)
reservoir_pressure = np.linspace(3000,4500,10)

# %%
df = pd.DataFrame({"depth":depth,"Porosity":porosity,"Permeability":perm,"reservoir_pressure":reservoir_pressure})

# %%
df
# Out:
#    depth   Porosity  Permeability  reservoir_pressure
# 0   1000  40.000000    500.000000         3000.000000
# 1   1500  36.666667    455.555556         3166.666667
# 2   2000  33.333333    411.111111         3333.333333
# 3   2500  30.000000    366.666667         3500.000000
# 4   3000  26.666667    322.222222         3666.666667
# 5   3500  23.333333    277.777778         3833.333333
# 6   4000  20.000000    233.333333         4000.000000
# 7   4500  16.666667    188.888889         4166.666667
# 8   5000  13.333333    144.444444         4333.333333
# 9   5500  10.000000    100.000000         4500.000000

# %%
df.plot()
# Out:
# <Axes: >

# %%
df.index = df["depth"]

# %%
df
# Out:
#        depth   Porosity  Permeability  reservoir_pressure
# depth
# 1000    1000  40.000000    500.000000         3000.000000
# 1500    1500  36.666667    455.555556         3166.666667
# 2000    2000  33.333333    411.111111         3333.333333
# 2500    2500  30.000000    366.666667         3500.000000
# 3000    3000  26.666667    322.222222         3666.666667
# 3500    3500  23.333333    277.777778         3833.333333
# 4000    4000  20.000000    233.333333         4000.000000
# 4500    4500  16.666667    188.888889         4166.666667
# 5000    5000  13.333333    144.444444         4333.333333
# 5500    5500  10.000000    100.000000         4500.000000

# %%
df.plot()
# Out:
# <Axes: xlabel='depth'>
